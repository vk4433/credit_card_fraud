# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix,precision_score,recall_score,f1_score
from imblearn.over_sampling import SMOTE
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV

# %%
data =pd.read_csv("creditcard.csv")
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
data.shape
# Out:
# (284807, 31)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
data.describe(include="all") # statistical analysis
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %% [markdown]
# ### preprocesing

# %%
data.isnull().sum() # check null values
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %% [markdown]
# #### scaling

# %%
ss = StandardScaler() ## performing scaling only the amount 
data["Amount"] = ss.fit_transform(pd.DataFrame(data["Amount"]))

# %%
data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
duplicate_rows = data[data.duplicated()]
duplicate_rows
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 33          26.0 -0.529912  0.873892  1.347247  0.145457  0.414209  0.100223
# 35          26.0 -0.535388  0.865268  1.351076  0.147575  0.433680  0.086983
# 113         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 114         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# 115         74.0  1.038370  0.127486  0.184456  1.109950  0.441699  0.945283
# ...          ...       ...       ...       ...       ...       ...       ...
# 282987  171288.0  1.912550 -0.455240 -1.750654  0.454324  2.089130  4.160019
# 283483  171627.0 -1.464380  1.368119  0.815992 -0.601282 -0.689115 -0.487154
# 283485  171627.0 -1.457978  1.378203  0.811515 -0.603760 -0.711883 -0.471672
# 284191  172233.0 -2.667936  3.160505 -3.355984  1.007845 -0.377397 -0.109730
# 284193  172233.0 -2.691642  3.123168 -3.339407  1.017018 -0.293095 -0.167054
#
# ...

# %%
duplicate_rows.shape
# Out:
# (1081, 31)

# %%
data = data.drop_duplicates()

# %%
data.shape
# Out:
# (283726, 31)

# %%
data.Class.value_counts()
# Out:
# Class
# 0    283253
# 1       473
# Name: count, dtype: int64

# %%
### removing Time becouse it not making impact
data.drop(columns="Time",axis=1,inplace=True)

# %%
data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9       V10  ...       V21       V22       V23       V24  \
# 0  0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928
# 1  0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846
# 2  0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281
# 3  0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575
# 4 -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458  0.141267
#
#         V25       V26       V27       V28    Amount  Class
# ...

# %% [markdown]
# ##### saving cleaned dataset

# %%
#data.to_csv("cleaned_credit.csv",index=False)

# %% [markdown]
# ### EDA

# %%
sns.countplot(data=data,x="Class")
# Out:
# <Axes: xlabel='Class', ylabel='count'>

# %% [markdown]
# #### correlation

# %%
plt.figure(figsize=(30,30))
sns.heatmap(data=data.corr(), annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# #### splitting the data

# %%
x = data.drop('Class', axis = 1) 
y=data['Class']

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %% [markdown]
# #### Model Training

# %%
model = {
    "LogisticRegression":LogisticRegression()
}
for name,mod in model.items():
    print(f"------{name}-----")
    mod.fit(X_train,y_train)
    n_pred = mod.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, n_pred)}") 
    print(f"\n Precision: {precision_score(y_test, n_pred)}") 
    print(f"\n Recall: {recall_score(y_test, n_pred)}") 
    print(f"\n F1 Score: {f1_score(y_test, n_pred)}")
# Out:
# ------LogisticRegression-----
#
#  Accuaracy: 0.9991717477883904
#
#  Precision: 0.8909090909090909
#
#  Recall: 0.5444444444444444
#
#  F1 Score: 0.6758620689655171

# %% [markdown]
# ##### it's an fraud detection problem we need mainly focus on precision (false positive)

# %% [markdown]
# ### undersamling

# %% [markdown]
# ##### we are performing undersamplig which means we  are equaling the number 0 to 1 . usally we may get loss of the data.

# %%
fraud = data[data["Class"]==1]
n_fraud = data[data["Class"]==0] # non-fraudulent transactions

# %%
fraud.shape
# Out:
# (473, 30)

# %%
n_fraud.shape
# Out:
# (283253, 30)

# %%
re_n_fraud =n_fraud.sample(len(fraud)) # we are taking sample from notfraud that equals the size of fraud

# %%
re_n_fraud.shape
# Out:
# (473, 30)

# %%
un_data = pd.concat([fraud,re_n_fraud],ignore_index=True) # concating both the dataframes

# %% [markdown]
# #### splitting the dataset

# %%
x = un_data.drop('Class', axis = 1) 
y=un_data['Class']

# %%
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
model = {
    "LogisticRegression":LogisticRegression()  ### model training and evoluting for undersampled data
}
for name,mod in model.items():
    print(f"------{name}-----")
    mod.fit(X_train,y_train)
    un_pred = mod.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, un_pred)}") 
    print(f"\n Precision: {precision_score(y_test, un_pred)}")
    print(f"\n Recall: {recall_score(y_test, un_pred)}") 
    print(f"\n F1 Score: {f1_score(y_test, un_pred)}")
# Out:
# ------LogisticRegression-----
#
#  Accuaracy: 0.9631578947368421
#
#  Precision: 0.9550561797752809
#
#  Recall: 0.9659090909090909
#
#  F1 Score: 0.96045197740113

# %% [markdown]
# ##### by doing undersampling we can look the there may be in increase precision

# %% [markdown]
# ### over sampling

# %%
x = data.drop('Class', axis = 1) 
y=data['Class']

# %%
x.shape,y.shape
# Out:
# ((283726, 29), (283726,))

# %%
x_reshape,y_reshape = SMOTE().fit_resample(x,y) ### we are using SMOTE to oversample the minority class

# %%
x_reshape.shape , y_reshape.shape
# Out:
# ((566506, 29), (566506,))

# %%
y_reshape.value_counts()
# Out:
# Class
# 0    283253
# 1    283253
# Name: count, dtype: int64

# %%
X_train,X_test,y_train,y_test = train_test_split(x_reshape,y_reshape,test_size=0.2,random_state=42)

# %%
model = {
    "LogisticRegression":LogisticRegression() ## training and testing the model by oversampling
}
for name,mod in model.items():
    print(f"------{name}-----")
    mod.fit(X_train,y_train)
    os_pred = mod.predict(X_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, os_pred)}") 
    print(f"\n Precision: {precision_score(y_test, os_pred)}")
    print(f"\n Recall: {recall_score(y_test, os_pred)}") 
    print(f"\n F1 Score: {f1_score(y_test, os_pred)}")
# Out:
# ------LogisticRegression-----
#
#  Accuaracy: 0.9445111295475808
#
#  Precision: 0.9726606328072406
#
#  Recall: 0.9151111032917539
#
#  F1 Score: 0.9430086570276027

# %% [markdown]
# ##### By doing oversampling we can see increse precision

# %% [markdown]
# #### Checking the oversample model with Xgboost

# %%
X_train,X_test,y_train,y_test = train_test_split(x_reshape,y_reshape,test_size=0.2,random_state=42)

# %%
xgc = XGBClassifier(
    objective='binary:logistic',
    max_depth=3,
    learning_rate=0.1,
    n_estimators=100,
    gini=0.3,
    loss='log_loss'
)

# %%
xgc
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gini=0.3, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, loss='log_loss',
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None, ...)

# %%
xgc.fit(X_train,y_train) #model training
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, gini=0.3, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, loss='log_loss',
#               max_bin=None, max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None, ...)

# %%
xg_pred = xgc.predict(X_test) # predicting the labels of the test set

# %% [markdown]
# #### confusion matrix

# %%
confusion_matrix(y_test,xg_pred)
# Out:
# array([[55778,   685],
#        [ 1929, 54910]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test,xg_pred),annot=True,cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# #### Evoluating the model

# %%
print(f"\nAccuracy: {accuracy_score(y_test, xg_pred)}") 
print(f"\nPrecision: {precision_score(y_test, xg_pred)}")
print(f"\nRecall: {recall_score(y_test, xg_pred)}") 
print(f"\nF1 Score: {f1_score(y_test, xg_pred)}")
# Out:
# Accuracy: 0.9769289156413832
#
# Precision: 0.9876787480888569
#
# Recall: 0.9660620348704235
#
# F1 Score: 0.9767508049166622

# %% [markdown]
# ### feature importances

# %%
xgc.feature_importances_
# Out:
# array([0.02217664, 0.01872733, 0.01881613, 0.04264932, 0.00620069,
#        0.00824589, 0.01802376, 0.0333697 , 0.01210637, 0.05014941,
#        0.02477484, 0.04379397, 0.01672119, 0.46368757, 0.00778955,
#        0.00560034, 0.03090054, 0.02084162, 0.01282715, 0.01364685,
#        0.01133895, 0.0149257 , 0.01462863, 0.01192134, 0.0137746 ,
#        0.01109552, 0.01317895, 0.0142852 , 0.02380229], dtype=float32)

# %%
plt.figure(figsize=(10,5))
vis = pd.Series(xgc.feature_importances_, index=x_reshape.columns)
vis.nlargest(20).plot(kind='barh')
plt.title("feature_importances")
plt.ylabel("features")
plt.show()

# %% [markdown]
# #### feature importance with shap

# %%
import shap
explainer = shap.TreeExplainer(xgc)
shap_values = explainer.shap_values(X_test)
shap.summary_plot(shap_values, X_test, plot_type="bar")

# %% [markdown]
# #### Hyperparameters by using Grid search

# %%
model = XGBClassifier()
params = {
    "n_estimators":[100,150,200,250],
    'learning_rate': [0.01, 0.1, 0.2],
    "max_depth":[3,5,7,9],
    'min_child_weight': [1, 3, 5],
    }
grid_search = GridSearchCV(estimator=model,param_grid=params,scoring="accuracy",cv=5,n_jobs=-1,verbose=2)

# %%
grid_search
# Out:
# GridSearchCV(cv=5, estimator={'LogisticRegression': LogisticRegression()},
#              n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 0.2],
#                          'max_depth': [3, 5, 7, 9],
#                          'min_child_weight': [1, 3, 5],
#                          'n_estimators': [100, 150, 200, 250]},
#              scoring='accuracy', verbose=2)

# %%
grid_search.fit(X_train, y_train)

# %%
print(f"Best parameters: {grid_search.best_params_}")
print(f"Best score: {grid_search.best_score_}")

# %% [markdown]
# ##### model predictions

# %%
import joblib
joblib.dump(xgc,"credit_prid_model.pkl")
# Out:
# ['credit_prid_model.pkl']

# %%
model = joblib.load("credit_prid_model.pkl")

# %%
input_data = np.array([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])

# Predict using the model
pred = model.predict(input_data)

# %%
if pred[0] == 0:
    print("coustomer is not fraud")
elif pred[0] == 1:
    print("customer is fraud")
else:
    print("unknown")
# Out:
# coustomer is not fraud
